# %% [markdown]
# # Interfaced Inductance vs Integrated Inductance

# %%
# This line configures matplotlib to show figures embedded in the notebook, 
# instead of opening a new window for each figure. 
# %matplotlib inline
# import plot tools and reload
import importlib
import PlotTools as pt
importlib.reload(pt)

# %% [markdown]
# ## Voltages

# %%
pt.plotResults('..\VisualStudio\DPSolverWin10\DPSolverWin10\data_vt.csv',1)
# Out:
# (49, 3)

# %%
pt.plotResults('..\VisualStudio\DPSolverWin10\DPSolverWin10\data_vt.csv',1)
# Out:
# (49, 3)

# %% [markdown]
# ## Currents

# %%
import importlib
import PlotTools as pt
importlib.reload(pt)
pt.plotResults('..\VisualStudio\DPSolverWin10\DPSolverWin10\data_j.csv',1)
# Out:
# (49, 3)

# %%
import importlib
import PlotTools as pt
importlib.reload(pt)
pt.plotResults('..\VisualStudio\DPSolverWin10\DPSolverWin10\data_j.csv',1)
# Out:
# (49, 3)
