# %% [markdown]
# # Synchronous Generator Unit Test

# %%
# This line configures matplotlib to show figures embedded in the notebook, 
# instead of opening a new window for each figure. 
# %matplotlib inline
# import plot tools and reload to run newest version
import importlib
import PlotTools as pt
importlib.reload(pt)
# Out:
# <module 'PlotTools' from 'N:\\Diss\\mmi\\git\\RESERVE\\DPsim\\PythonTools\\PlotTools.py'>

# %% [markdown]
# ## Voltages

# %%
pt.plotResultsSynGenUnitTest('..\VisualStudio\DPSolverWin10\DPSolverWin10\data_vt.csv',1,2,3)
# Out:
# (2001, 7)

# %% [markdown]
# ## Currents

# %%
pt.plotResultsSynGenUnitTest('..\VisualStudio\DPSolverWin10\DPSolverWin10\data_j.csv',1,2,3)
# Out:
# (2001, 7)
