# %%
# Configure matplotlib to show figures embedded in the notebook 
# %matplotlib inline
# Import plot tools and reload
import importlib
import PlotTools as pt
importlib.reload(pt)
# Define path to CSV files
LogPath = '../VisualStudio/DPsimVS2015/Logs/'

# %% [markdown]
# ## Comparison of dynamic phasors and EMT for increasing time steps
# The circuit below is simulated. The voltage source (V = 1000) with resistance (R = 1) is implemented as Norton equivalent. The RX-series element represents a line (R = 1, L = 1). At 0.1 seconds, the load resistance is changed from R = 100 to R = 50.  The frequency of the voltage source changes from 50 Hz to 40 Hz at 0.2 seconds.
# ![Circuit](line_load.png)

# %% [markdown]
# ### Time step 50 µs

# %%
pt.plotNodeVoltageDpEmt( \
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoad_5e-05.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',3)

# %% [markdown]
# ### Time step 1 ms

# %%
pt.plotNodeVoltageDpEmtRef( \
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoad_0.001.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_0.001.csv',3)

# %% [markdown]
# ### Time step 5 ms

# %%
pt.plotNodeVoltageDpEmtRef( \
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoad_0.005.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_0.005.csv',3)

# %% [markdown]
# ### Time step 10 ms

# %%
importlib.reload(pt)
pt.plotNodeVoltageDpEmtRef( \
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoad_0.01.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_0.01.csv',3)

# %% [markdown]
# ### Time step 15 ms

# %%
pt.plotNodeVoltageDpEmtRef( \
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoad_0.015.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_0.015.csv',3)

# %% [markdown]
# ### Time step 20 ms

# %%
pt.plotNodeVoltageDpEmtRef( \
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoad_0.02.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_0.02.csv',3)

# %% [markdown]
# ## Dynamic Phasors with interpolation before frequency shift

# %% [markdown]
# Since the 50 Hz fundamental is implicitly included in the dynamic phasor solution, we could linearly interpolate the real and imaginary component before calculating the shifted signal.
#
# ### Time step 20 ms

# %%
pt.plotNodeVoltageInterpDpRef( \
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoad_0.02.csv',3)

# %% [markdown]
# The transients of this simulation scenario are quite fast. In steady state the results look much better. The following plot shows a simulation over one second.

# %%
pt.plotNodeVoltageInterpDpRef( \
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05_1.csv',
    LogPath + 'LeftVectorLog_VarFreqRXLineResLoad_0.02_1.csv',3)
