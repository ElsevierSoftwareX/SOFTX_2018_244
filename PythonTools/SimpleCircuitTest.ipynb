# %%
# This line configures matplotlib to show figures embedded in the notebook, 
# instead of opening a new window for each figure. 
#%matplotlib inline
# import plot tools and reload
import importlib
import PlotTools as pt
importlib.reload(pt)
# Out:
# <module 'PlotTools' from 'C:\\Users\\mmi\\Documents\\git\\DPsim\\PythonTools\\PlotTools.py'>

# %% [markdown]
# ## Comparison of dynamic phasors and EMT for increasing time steps

# %%
importlib.reload(pt)
pt.plotNodeVoltageDpEmt('..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoad_5e-05.csv',
                        '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',3)

# %%
importlib.reload(pt)
pt.plotNodeVoltageDpEmtRef('..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
                           '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoad_0.001.csv',
                        '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_0.001.csv',3)

# %%
importlib.reload(pt)
pt.plotNodeVoltageDpEmtRef('..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
                           '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoad_0.005.csv',
                        '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_0.005.csv',3)

# %%
importlib.reload(pt)
pt.plotNodeVoltageDpEmtRef('..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
                           '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoad_0.01.csv',
                        '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_0.01.csv',3)

# %%
importlib.reload(pt)
pt.plotNodeVoltageDpEmtRef('..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
                           '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoad_0.015.csv',
                        '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_0.015.csv',3)

# %%
importlib.reload(pt)
pt.plotNodeVoltageDpEmtRef('..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
                           '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoad_0.02.csv',
                        '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_0.02.csv',3)

# %% [markdown]
# ## Dynamic Phasors with interpolation before frequency shift

# %%
importlib.reload(pt)
pt.plotNodeVoltageInterpDpRef('..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoadEMT_5e-05.csv',
                           '..\VisualStudio\DPsimVS2015\Logs\LeftVectorLog_VarFreqRXLineResLoad_0.02.csv',3)
