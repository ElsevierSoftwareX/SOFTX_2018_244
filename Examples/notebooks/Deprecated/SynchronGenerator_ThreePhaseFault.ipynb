# %% [markdown]
# # Synchronous Generator Three Phase Fault

# %%
# This line configures matplotlib to show figures embedded in the notebook, 
# instead of opening a new window for each figure. 
#%matplotlib inline
# import plot tools and reload
import importlib
import PlotTools as pt
importlib.reload(pt)
# Out:
# <module 'PlotTools' from 'C:\\Users\\mmi\\Documents\\git\\DPsim\\PythonTools\\PlotTools.py'>

# %% [markdown]
# ## Voltages

# %%
#%matplotlib
pt.plotResultsSynGenUnitTest('..\VisualStudio\DPsimVS2015\data_vt.csv',1,2,3)
# Out:
# (1000, 7)

# %% [markdown]
# ## Currents

# %%
#%matplotlib
pt.plotResultsSynGenUnitTest('..\VisualStudio\DPsimVS2015\data_j.csv',1,2,3)
# Out:
# (1000, 7)

# %% [markdown]
# ## Variablen

# %%
#%matplotlib
pt.plotResultsSynGenUnitTestVar('..\VisualStudio\DPsimVS2015\data_synGen_curr.csv', 6)
# Out:
# (1000, 8)
